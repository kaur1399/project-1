# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import image
from sklearn.metrics import accuracy_score
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Convolution2D, Flatten, MaxPooling2D, Reshape, InputLayer
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.preprocessing.image import load_img

from keras.optimizers import RMSprop,SGD,Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau


path = r'facial-expression-recognition/'
os.listdir(path)
data = pd.read_csv(path+'icml_face_data.csv')
#data.head()
def prepare_data(data):
    """ Prepare data for modeling 
        input: data frame with labels und pixel data
        output: image and label array """
    
    image_array = np.zeros(shape=(len(data), 48, 48))
    image_label = np.array(list(map(int, data['emotion'])))
    
    for i, row in enumerate(data.index):
        image = np.fromstring(data.loc[row, ' pixels'], dtype=int, sep=' ')
        image = np.reshape(image, (48, 48))
        image_array[i] = image
        
    return image_array, image_label


train_image_array, train_image_label = prepare_data(data[data[' Usage']=='Training'])
val_image_array, val_image_label = prepare_data(data[data[' Usage']=='PrivateTest'])
test_image_array, test_image_label = prepare_data(data[data[' Usage']=='PublicTest'])

train_images = train_image_array.reshape((train_image_array.shape[0], 48, 48, 1))
X_train = train_images.astype('float32')/255
val_images = val_image_array.reshape((val_image_array.shape[0], 48, 48, 1))
X_val = val_images.astype('float32')/255
test_images = test_image_array.reshape((test_image_array.shape[0], 48, 48, 1))
X_test = test_images.astype('float32')/255

y_train = keras.utils.to_categorical(train_image_label)
y_val = keras.utils.to_categorical(val_image_label)
y_test = keras.utils.to_categorical(test_image_label)
#keras.utils.to_categorical(train['label'].values)

pd.DataFrame(y_train)

# With data augmentation to prevent overfitting
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(X_train)

# define vars
input_reshape = (48, 48, 1)

pool_size = (2, 2)

hidden_num_units = 265
output_num_units = 7

epochs = 10
batch_size = 128

model = Sequential()
#Block-1
model.add(Convolution2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = input_reshape))
model.add(MaxPooling2D((2,2) , strides = 2 , padding = 'same'))
model.add(Convolution2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(MaxPooling2D((2,2) , strides = 2 , padding = 'same'))
model.add(Dropout(0.2))

#Block-2
model.add(Convolution2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = input_reshape))
model.add(MaxPooling2D((2,2) , strides = 2 , padding = 'same'))
model.add(Convolution2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(MaxPooling2D((2,2) , strides = 2 , padding = 'same'))
model.add(Dropout(0.2))

#Block-3
model.add(Convolution2D(75 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = input_reshape))
model.add(MaxPooling2D((2,2) , strides = 2 , padding = 'same'))
model.add(Convolution2D(50 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(MaxPooling2D((2,2) , strides = 2 , padding = 'same'))
model.add(Dropout(0.2))

#Block-4
model.add(Convolution2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = input_reshape))
model.add(MaxPooling2D((2,2) , strides = 2 , padding = 'same'))
model.add(Convolution2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(MaxPooling2D((2,2) , strides = 2 , padding = 'same'))
model.add(Dropout(0.2))

#Block-5
model.add(Flatten())
model.add(Dense(units = 256 , activation = 'relu'))
model.add(Dropout(0.3))

#Block-6
model.add(Dense(units = 7 , activation = 'softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])
model.summary()

checkpoint = ModelCheckpoint('EmotionDetectionModel.h5',
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1)
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True
                          )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)
callbacks = [earlystop,checkpoint,reduce_lr]
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
trained_model_conv = model.fit(X_train, y_train, epochs =20, batch_size=128,callbacks=callbacks, validation_data=(X_val, y_val))


plt.plot(trained_model_conv.history['loss'],label='Train Loss')
plt.plot(trained_model_conv.history['val_loss'],label='Val Loss')
plt.xlabel('Ephocs')
plt.ylabel('loss')
plt.legend()
plt.show()
model.save("Emotion_little_vggi.h5")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 256)       2560
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 256)       590080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 128)       295040
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 75)          86475
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 75)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 50)          33800
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 50)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 50)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 64)          28864
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 64)          36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 256)               16640
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 1,239,770
# Trainable params: 1,239,770
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 225/225 [==============================] - 680s 3s/step - loss: 1.8278 - accuracy: 0.2484 - val_loss: 1.8165 - val_accuracy: 0.2449
#
# Epoch 00001: val_loss improved from inf to 1.81655, saving model to EmotionDetectionModel.h5
# Epoch 2/20
# 225/225 [==============================] - 711s 3s/step - loss: 1.8128 - accuracy: 0.2513 - val_loss: 1.8158 - val_accuracy: 0.2449
#
# Epoch 00002: val_loss improved from 1.81655 to 1.81583, saving model to EmotionDetectionModel.h5
# Epoch 3/20
# 225/225 [==============================] - 714s 3s/step - loss: 1.8124 - accuracy: 0.2513 - val_loss: 1.8149 - val_accuracy: 0.2449
#
# Epoch 00003: val_loss improved from 1.81583 to 1.81487, saving model to EmotionDetectionModel.h5
# Epoch 4/20
# 225/225 [==============================] - 694s 3s/step - loss: 1.7922 - accuracy: 0.2564 - val_loss: 1.7663 - val_accuracy: 0.2666
#
# Epoch 00004: val_loss improved from 1.81487 to 1.76635, saving model to EmotionDetectionModel.h5
# Epoch 5/20
# 225/225 [==============================] - 695s 3s/step - loss: 1.6900 - accuracy: 0.3055 - val_loss: 1.6262 - val_accuracy: 0.3355
#
# Epoch 00005: val_loss improved from 1.76635 to 1.62623, saving model to EmotionDetectionModel.h5
# Epoch 6/20
# 225/225 [==============================] - 699s 3s/step - loss: 1.5717 - accuracy: 0.3633 - val_loss: 1.4834 - val_accuracy: 0.4057
#
# Epoch 00006: val_loss improved from 1.62623 to 1.48340, saving model to EmotionDetectionModel.h5
# Epoch 7/20
# 225/225 [==============================] - 702s 3s/step - loss: 1.4459 - accuracy: 0.4138 - val_loss: 1.3930 - val_accuracy: 0.4416
#
# Epoch 00007: val_loss improved from 1.48340 to 1.39298, saving model to EmotionDetectionModel.h5
# Epoch 8/20
# 225/225 [==============================] - 704s 3s/step - loss: 1.3956 - accuracy: 0.4344 - val_loss: 1.3641 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss improved from 1.39298 to 1.36412, saving model to EmotionDetectionModel.h5
# Epoch 9/20
# 225/225 [==============================] - 698s 3s/step - loss: 1.3475 - accuracy: 0.4598 - val_loss: 1.3585 - val_accuracy: 0.4583
#
# Epoch 00009: val_loss improved from 1.36412 to 1.35846, saving model to EmotionDetectionModel.h5
# Epoch 10/20
# 225/225 [==============================] - 712s 3s/step - loss: 1.3052 - accuracy: 0.4810 - val_loss: 1.2795 - val_accuracy: 0.4932
#
# Epoch 00010: val_loss improved from 1.35846 to 1.27954, saving model to EmotionDetectionModel.h5
# Epoch 11/20
# 225/225 [==============================] - 706s 3s/step - loss: 1.2701 - accuracy: 0.4992 - val_loss: 1.2479 - val_accuracy: 0.5160
#
# Epoch 00011: val_loss improved from 1.27954 to 1.24793, saving model to EmotionDetectionModel.h5
# Epoch 12/20
# 225/225 [==============================] - 715s 3s/step - loss: 1.2245 - accuracy: 0.5196 - val_loss: 1.2301 - val_accuracy: 0.5169
#
# Epoch 00012: val_loss improved from 1.24793 to 1.23012, saving model to EmotionDetectionModel.h5
# Epoch 13/20
# 225/225 [==============================] - 730s 3s/step - loss: 1.1953 - accuracy: 0.5378 - val_loss: 1.2076 - val_accuracy: 0.5322
#
# Epoch 00013: val_loss improved from 1.23012 to 1.20762, saving model to EmotionDetectionModel.h5
# Epoch 14/20
# 225/225 [==============================] - 729s 3s/step - loss: 1.1662 - accuracy: 0.5475 - val_loss: 1.2157 - val_accuracy: 0.5171
#
# Epoch 00014: val_loss did not improve from 1.20762
# Epoch 15/20
# 225/225 [==============================] - 707s 3s/step - loss: 1.1428 - accuracy: 0.5609 - val_loss: 1.1861 - val_accuracy: 0.5344
#
# Epoch 00015: val_loss improved from 1.20762 to 1.18606, saving model to EmotionDetectionModel.h5
# Epoch 16/20
# 225/225 [==============================] - 733s 3s/step - loss: 1.1111 - accuracy: 0.5699 - val_loss: 1.1851 - val_accuracy: 0.5397
#
# Epoch 00016: val_loss improved from 1.18606 to 1.18511, saving model to EmotionDetectionModel.h5
# Epoch 17/20
# 225/225 [==============================] - 734s 3s/step - loss: 1.0914 - accuracy: 0.5785 - val_loss: 1.1723 - val_accuracy: 0.5430
#
# Epoch 00017: val_loss improved from 1.18511 to 1.17227, saving model to EmotionDetectionModel.h5
# Epoch 18/20
# 225/225 [==============================] - 695s 3s/step - loss: 1.0729 - accuracy: 0.5877 - val_loss: 1.1819 - val_accuracy: 0.5461
#
# Epoch 00018: val_loss did not improve from 1.17227
# Epoch 19/20
# 225/225 [==============================] - 713s 3s/step - loss: 1.0489 - accuracy: 0.6003 - val_loss: 1.1802 - val_accuracy: 0.5545
#
# Epoch 00019: val_loss did not improve from 1.17227
# Epoch 20/20
# 225/225 [==============================] - 716s 3s/step - loss: 1.0273 - accuracy: 0.6080 - val_loss: 1.1826 - val_accuracy: 0.5500
# Restoring model weights from the end of the best epoch.
#
# Epoch 00020: val_loss did not improve from 1.17227
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 00020: early stopping
